# %% [markdown]
# ## Binary Tree Preorder Traversal (144)
# 根左右
# ### recursive

# %%
class Solution(object):
    def preorderTraversal(self, root):
        """
        :type root: TreeNode
        :rtype: List[int]
        """
        res = []
        self.dfs(root, res)
        return res
    
    def dfs(self, root, res):
        if root:
            res.append(root.val)
            self.dfs(root.left, res)
            self.dfs(root.right, res)

# %% [markdown]
# ### iterative(!!!!)
# LIFO

# %%
class Solution(object):
    def preorderTraversal(self, root):
        """
        :type root: TreeNode
        :rtype: List[int]
        """
        res = []
        stack = [root]
        while stack:
            node = stack.pop()
            if node:
                res.append(node.val)
                stack.append(node.right)
                stack.append(node.left)
        return res

# %% [markdown]
# ## Binary Tree Inorder Traversal(94)
# 左中右
# ### recursive

# %%
class Solution(object):
    def inorderTraversal(self, root):
        """
        :type root: TreeNode
        :rtype: List[int]
        """
        res = []
        self.helper(root, res)
        return res
    
    def helper(self, root, res):
        if root:
            if root.left:
                self.helper(root.left, res)
            res.append(root.val)
            if root.right:
                self.helper(root.right, res)

# %% [markdown]
# ### iterative

# %%
# Definition for a binary tree node.
# class TreeNode(object):
#     def __init__(self, x):
#         self.val = x
#         self.left = None
#         self.right = None

class Solution(object):
    def inorderTraversal(self, root):
        """
        :type root: TreeNode
        :rtype: List[int]
        """
        res = []
        stack = []
        curr = root
        while curr or stack:           # while stack because when reaching the bottom, curr = None
            while curr:
                stack.append(curr)
                curr = curr.left
            curr = stack.pop()
            res.append(curr.val)
            curr = curr.right
        return res

# %% [markdown]
# ## Binary Tree Postorder Traversal(145)
# 左右中
# ### recursive

# %%
class Solution(object):
    def postorderTraversal(self, root):
        """
        :type root: TreeNode
        :rtype: List[int]
        """
        res = []
        self.helper(root, res)
        return res
    
    def helper(self, root, res):
        if root:
            if root.left:
                self.helper(root.left, res)
            if root.right:
                self.helper(root.right, res)
            res.append(root.val)

# %% [markdown]
# ### iterative
# a complete reverse of preorder

# %%
class Solution(object):
    def postorderTraversal(self, root):
        """
        :type root: TreeNode
        :rtype: List[int]
        """
        res = []
        stack = [root]
        while stack:
            node = stack.pop()
            if node:
                res.insert(0, node.val)
                stack.append(node.left)
                stack.append(node.right)  
        return res

# %% [markdown]
# ## Binary Tree Level Order Traversal(102)
# ### recursive

# %%
class Solution(object):
    def levelOrder(self, root):
        """
        :type root: TreeNode
        :rtype: List[List[int]]
        """
        sol = [[]]
        self.helper(root, 1, sol)
        return sol[:-1]
    
    def helper(self, node, level, sol):
        if not node:
            return
        else:
            sol[level-1].append(node.val)
            if len(sol) == level:  
                sol.append([])
            self.helper(node.left, level+1, sol)
            self.helper(node.right, level+1, sol)

# %% [markdown]
# ### iterative

# %%
from collections import deque

class Solution(object):
    def levelOrder(self, root):
        """
        :type root: TreeNode
        :rtype: List[List[int]]
        """
        if not root: return []
        queue, res = deque([root]), []
        
        while queue:
            curr_level, length = [], len(queue)
            for _ in range(length):
                node = queue.popleft()
                if node:
                    curr_level.append(node.val)
                    queue.append(node.left)
                    queue.append(node.right)
            #if curr_level:
                #res.append(curr_level)
        #return res
            res.append(curr_level)
        return res[:-1]

# %%
# 100
# iterative mine
class Solution(object):
    def isSameTree(self, p, q):
        """
        :type p: TreeNode
        :type q: TreeNode
        :rtype: bool
        """
        stack_p, stack_q = [p], [q]
        while stack_p and stack_q:
            node_p = stack_p.pop()
            node_q = stack_q.pop()
            if node_p or node_q:
                if not node_p: return False
                if not node_q: return False
                if node_p.val != node_q.val:
                    return False
                if node_p:
                    stack_p.append(node_p.right)
                    stack_p.append(node_p.left)
                if node_q:
                    stack_q.append(node_q.right)
                    stack_q.append(node_q.left)
        return True

# better
class Solution(object):
    def isSameTree(self, p, q):
        """
        :type p: TreeNode
        :type q: TreeNode
        :rtype: bool
        """
        stack = [(p, q)]
        while stack:
            node_p, node_q = stack.pop()
            if not node_p and not node_q: continue
            if not node_p or not node_q: return False # donot need to return node_p == node_q
            if node_p.val != node_q.val: return False
            stack.append((node_p.right, node_q.right))
            stack.append((node_p.left, node_q.left))
        return True

# recursive DFS
class Solution(object):
    def isSameTree(self, p, q):
        """
        :type p: TreeNode
        :type q: TreeNode
        :rtype: bool
        """
        if not p or not q: return p == q
        if p.val != q.val: return False
        
        left = self.isSameTree(p.left, q.left)
        right = self.isSameTree(p.right, q.right)
        return left and right

# %%
# 101
# recursive
class Solution(object):
    def isSymmetric(self, root):
        """
        :type root: TreeNode
        :rtype: bool
        """
        def isSym(L, R):
            if L and R and L.val == R.val:
                return isSym(L.left, R.right) and isSym(L.right, R.left)
            return L == R
        return not root or isSym(root.left, root.right)

# iterative
from collections import deque

class Solution(object):
    def isSymmetric(self, root):
        """
        :type root: TreeNode
        :rtype: bool
        """
        if not root:
            return True
        
        queue = deque([(root.left, root.right)])
        while queue:
            node1, node2 = queue.popleft()
            if not node1 and not node2: continue
            if not node1 or not node2: return False
            if node1.val != node2.val:
                return False
            queue.append((node1.left, node2.right))
            queue.append((node1.right, node2.left))
        return True

# %%
# 226
# recursive
class Solution(object):
    def invertTree(self, root):
        """
        :type root: TreeNode
        :rtype: TreeNode
        """
        if not root:
            return root
        
        root.left, root.right = self.invertTree(root.right), self.invertTree(root.left)
        #right = self.invertTree(root.right)
        #left = self.invertTree(root.left)
        #root.left = right
        #root.right = left

        return root

# iterative BFS
from collections import deque

class Solution(object):
    def invertTree(self, root):
        """
        :type root: TreeNode
        :rtype: TreeNode
        """
        queue = deque([root])
        while queue:
            node = queue.popleft()
            if node:
                node.left, node.right = node.right, node.left
                queue.extend([node.left, node.right])
        return root

# iterative DFS
class Solution(object):
    def invertTree(self, root):
        """
        :type root: TreeNode
        :rtype: TreeNode
        """
        stack = [root]
        while stack:
            node = stack.pop()
            if node:
                node.right, node.left = node.left, node.right
                stack.extend([node.right, node.left])
        return root

# %%
# 257 DFS
from collections import deque

class Solution(object):
    def binaryTreePaths(self, root):
        """
        :type root: TreeNode
        :rtype: List[str]
        """
        if not root:
            return []
        
        res, queue = [], deque([(root, "")])
        while queue:
            node, ls = queue.popleft()
            if not node.left and not node.right:
                res.append(ls + str(node.val))
            if node.left:
                queue.append((node.left, ls + str(node.val) + "->"))
            if node.right:
                queue.append((node.right, ls + str(node.val) + "->"))
        return res
    
# BFS
class Solution(object):
    def binaryTreePaths(self, root):
        """
        :type root: TreeNode
        :rtype: List[str]
        """
        if not root:
            return []
        
        res, stack = [], [(root, "")]
        while stack:
            node, ls = stack.pop()
            if not node.left and not node.right:
                res.append(ls + str(node.val))
            if node.right:
                stack.append((node.right, ls + str(node.val) + "->"))
            if node.left:
                stack.append((node.left, ls + str(node.val) + "->"))
        return res

# recursive
class Solution(object):
    def binaryTreePaths(self, root):
        """
        :type root: TreeNode
        :rtype: List[str]
        """
        if not root:
            return []
        
        res = []
        self.helper(root, "", res)
        return res
    
    def helper(self, root, ls, res):
        if not root.left and not root.right:
            res.append(ls + str(root.val))
        if root.left:
            self.helper(root.left, ls + str(root.val) + "->", res)
        if root.right:
            self.helper(root.right, ls + str(root.val) + "->", res)

# %%
# 112
# DFS
class Solution(object):
    def hasPathSum(self, root, sum):
        """
        :type root: TreeNode
        :type sum: int
        :rtype: bool
        """
        if not root:
            return False
        
        stack = [(root, 0)]
        while stack:
            node, val = stack.pop()
            if not node.left and not node.right:
                if val + node.val == sum: return True
            if node.left:
                stack.append((node.left, val + node.val))
            if node.right:
                stack.append((node.right, val + node.val))
        return False
    
# BFS
# recursive
class Solution(object):
    def hasPathSum(self, root, sum):
        """
        :type root: TreeNode
        :type sum: int
        :rtype: bool
        """
        if not root:
            return False
        val = 0
        res = [] ############################################################################################
        self.helper(root, val, sum, res)
        return any(res)
    
    def helper(self, root, val, sum, res):
        if not root.left and not root.right:
            if val + root.val == sum:
                res.append(True)
        if root.left:
            self.helper(root.left, val + root.val, sum, res)
        if root.right:
            self.helper(root.right, val + root.val, sum, res)

# %%
# 113
# BFS
# notice the usage of array list!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
class Solution(object):
    def pathSum(self, root, s):
        """
        :type root: TreeNode
        :type sum: int
        :rtype: List[List[int]]
        """
        if not root:
            return []
        
        res = []
        val = 0
        stack = [(root, [root.val])]
        while stack:
            node, path = stack.pop()
            if not node.left and not node.right and sum(path) == s:
                res.append(path)
            if node.left:
                stack.append((node.left, path + [node.left.val]))
            if node.right:
                stack.append((node.right, path + [node.right.val]))
        return res

# recursive
class Solution(object):
    def pathSum(self, root, s):
        """
        :type root: TreeNode
        :type sum: int
        :rtype: List[List[int]]
        """
        if not root:
            return []
        
        res = []
        self.helper(root, res, [root.val], s)
        return res
    
    def helper(self, root, res, path, s):
        if not root.left and not root.right and sum(path) == s:
            res.append(path)
        if root.left:
            self.helper(root.left, res, path + [root.left.val], s)
        if root.right:
            self.helper(root.right, res, path + [root.right.val], s)

# %%
# 129
# mine
class Solution(object):
    def sumNumbers(self, root):
        """
        :type root: TreeNode
        :rtype: int
        """
        if not root:
            return 0
        res = 0
        stack = [(root, "")]
        while stack:
            node, val_str = stack.pop()
            if not node.left and not node.right:
                res += int(val_str + str(node.val))
            if node.left:
                stack.append((node.left, val_str + str(node.val)))
            if node.right:
                stack.append((node.right, val_str + str(node.val)))
        return res
# or
class Solution(object):
    def sumNumbers(self, root):
        """
        :type root: TreeNode
        :rtype: int
        """
        if not root:
            return 0
        res = 0
        stack = [(root, 0)]
        while stack:
            node, val = stack.pop()
            if not node.left and not node.right:
                res += val * 10 + node.val
            if node.left:
                stack.append((node.left, val * 10 + node.val))
            if node.right:
                stack.append((node.right, val * 10 + node.val))
        return res

# recursive better
class Solution(object):
    def sumNumbers(self, root):
        """
        :type root: TreeNode
        :rtype: int
        """
        return self.helper(root, 0)
    
    def helper(self, node, val):
        if not node:
            return 0
        val = val * 10 + node.val
        if not node.left and not node.right:
            return val
        return self.helper(node.left, val) + self.helper(node.right, val)

# %%
# 298 lock

# %%
# 111
# DFS
class Solution(object):
    def minDepth(self, root):
        """
        :type root: TreeNode
        :rtype: int
        """
        if not root:
            return 0
        res = []
        stack = [(root, 0)]
        while stack:
            node, times = stack.pop()
            if not node.left and not node.right:
                res.append(times + 1)
            if node.left:
                stack.append((node.left, times + 1))
            if node.right:
                stack.append((node.right, times + 1))
        return min(res)
    
# BFS ----- theoretically better
from collections import deque

class Solution(object):
    def minDepth(self, root):
        """
        :type root: TreeNode
        :rtype: int
        """
        if not root:
            return 0
        queue = deque([root])
        depth = 0
        while queue:
            depth += 1
            length = len(queue)
            for _ in range(length):
                node = queue.popleft()
                if node:
                    if not node.left and not node.right:
                        return depth
                    queue.append(node.left)
                    queue.append(node.right)
        return depth

# recursive ###
class Solution(object):
    def minDepth(self, root):
        """
        :type root: TreeNode
        :rtype: int
        """
        if not root:
            return 0
        if not root.left or not root.right:
            return self.minDepth(root.left) + self.minDepth(root.right) + 1
        return min(self.minDepth(root.left), self.minDepth(root.right)) + 1

# %% [markdown]
# <font color=red> 注意最大深度和最小深度的区别!!!!!!!!!!!!!!!!!!!!!!! </font>

# %%
# 104
# iterative
class Solution(object):
    def maxDepth(self, root):
        """
        :type root: TreeNode
        :rtype: int
        """
        if not root:
            return 0
        res = []
        stack = [(root, 1)]
        while stack:
            node, depth = stack.pop()
            if not node.left and not node.right:
                res.append(depth)
            if node.left:
                stack.append((node.left, depth + 1))
            if node.right:
                stack.append((node.right, depth + 1))
        return max(res)

# recursive
class Solution(object):
    def maxDepth(self, root):
        """
        :type root: TreeNode
        :rtype: int
        """
        if not root:
            return 0
        if not root.left or not root.left:
            return self.maxDepth(root.left) + self.maxDepth(root.right) + 1
        return max(self.maxDepth(root.left), self.maxDepth(root.right)) + 1

# %%
# 110 ############################################################################################
# very slow
class Solution(object):
    def isBalanced(self, root):
        """
        :type root: TreeNode
        :rtype: bool
        """
        if not root:
            return True
        diff = self.get_height(root.left) - self.get_height(root.right)
        # better to check this first
        if abs(diff) > 1:
            return False
        return self.isBalanced(root.right) and self.isBalanced(root.left)
        
    def get_height(self, root):
        if not root:
            return 0
        res = []
        stack = [(root, 1)]
        while stack:
            node, depth = stack.pop()
            if not node.left and not node.right:
                res.append(depth)
            if node.left:
                stack.append((node.left, depth + 1))
            if node.right:
                stack.append((node.right, depth + 1))
        return max(res)

# much better
class Solution(object):
    def isBalanced(self, root):
        """
        :type root: TreeNode
        :rtype: bool
        """
        height = self.get_height(root)
        return height != -1
        
    def get_height(self, root):
        if not root: return 0
        left = self.get_height(root.left)
        right = self.get_height(root.right)
        if left == -1 or right == -1 : return -1          
        if abs(left - right) > 1:  return -1
        return max(left, right) + 1

# %%
# 124 ##################################################################################################
class Solution(object):
    curr_max = float("-inf")
    def maxPathSum(self, root):
        """
        :type root: TreeNode
        :rtype: int
        """
        self.helper(root)
        return self.curr_max
    
    def helper(self, root):
        if not root:
            return 0
        left = self.helper(root.left)
        right = self.helper(root.right)
        left = left if left > 0 else 0
        right = right if right > 0 else 0
        self.curr_max = max(left + right + root.val, self.curr_max)
        return max(left, right) + root.val

# %%
# 250 lock

# %%
# 366 lock

# %%
# 337
class Solution(object):
    def rob(self, root):
        """
        :type root: TreeNode
        :rtype: int
        """
        return max(self.helper(root))
    
    def helper(self, node):
        # tuple contain rob now and rob latter
        if not node:
            return (0, 0)
        left, right = self.helper(node.left), self.helper(node.right)
        now = node.val + left[1] + right[1]
        latter = max(left) + max(right)
        return (now, latter)

# %%
# 107
from collections import deque

class Solution(object):
    def levelOrderBottom(self, root):
        """
        :type root: TreeNode
        :rtype: List[List[int]]
        """
        if not root:
            return []
        res = []
        queue = deque([root])
        while queue:
            length = len(queue)
            curr = []
            for _ in range(length):
                node = queue.popleft()
                curr.append(node.val)
                if node.left:
                    queue.append(node.left)
                if node.right:
                    queue.append(node.right)
            res.insert(0, curr)
        return res

# %%
# 103
from collections import deque

class Solution(object):
    def zigzagLevelOrder(self, root):
        """
        :type root: TreeNode
        :rtype: List[List[int]]
        """
        if not root:
            return []
        res, queue = [], deque([root])
        level = 0
        while queue:
            level += 1
            curr = []
            length = len(queue)
            for _ in range(length):
                node = queue.popleft()
                if level % 2 == 0:
                    curr.insert(0, node.val)
                else:
                    curr.append(node.val)
                if node.left:
                    queue.append(node.left)
                if node.right:
                    queue.append(node.right)
            res.append(curr)
        return res

# %%
# 199
from collections import deque

class Solution(object):
    def rightSideView(self, root):
        """
        :type root: TreeNode
        :rtype: List[int]
        """
        if not root:
            return []
        res, queue = [], deque([root])
        level = 0
        while queue:
            level += 1
            curr = []
            length = len(queue)
            for _ in range(length):
                node = queue.popleft()
                curr.append(node.val)
                if node.left:
                    queue.append(node.left)
                if node.right:
                    queue.append(node.right)
            res.append(curr[-1])
        return res

# %%
# 98
# use inorder 
class Solution(object):
    isBST = True
    def isValidBST(self, root):
        """
        :type root: TreeNode
        :rtype: bool
        """
        if not root:
            return True
        res = []
        self.helper(root, res)
        for i in range(len(res) - 1):
            if res[i] >= res[i + 1]:
                return False
        return True
        
    def helper(self, root, res):
        if root.left:
            self.helper(root.left, res)
        res.append(root.val)
        if root.right:
            self.helper(root.right, res)

class Solution(object):
    isBST = True
    def isValidBST(self, root):
        """
        :type root: TreeNode
        :rtype: bool
        """
        if not root:
            return True
        res = []
        stack = []
        curr = root
        while curr or stack:
            while curr:
                stack.append(curr)
                curr = curr.left
            curr = stack.pop()
            res.append(curr.val)
            curr = curr.right
        for i in range(len(res) - 1):
            if res[i] >= res[i + 1]:
                return False
        return True

# better iterative
class Solution(object):
    isBST = True
    def isValidBST(self, root, left = float('-inf'), right = float('inf')):
        """
        :type root: TreeNode
        :rtype: bool
        """
        if not root:
            return True
        if root.val <= left or root.val >= right:
            return False
        return self.isValidBST(root.left, left, root.val) and\
               self.isValidBST(root.right, root.val, right)

# %%
#235

# %%
# 116
from collections import deque

class Solution(object):
    def connect(self, root):
        """
        :type root: Node
        :rtype: Node
        """
        if not root:
            return root
        #layer = []
        queue = deque([root])
        last = root
        while queue:
            length = len(queue)
            for i in range(length):
                node = queue.popleft()
                if node:
                    if i == 0:
                        last = node
                    else:
                        last.next = node
                        last = node
                    queue.append(node.left)
                    queue.append(node.right)
            last.next = None
        return root

# %%
# 117
from collections import deque

class Solution(object):
    def connect(self, root):
        """
        :type root: Node
        :rtype: Node
        """
        if not root:
            return root
        #layer = []
        queue = deque([root])
        last = root
        while queue:
            length = len(queue)
            for i in range(length):
                node = queue.popleft()
                if i == 0:
                    last = node
                else:
                    last.next = node
                    last = node
                if node.left:
                    queue.append(node.left)
                if node.right:
                    queue.append(node.right)
            last.next = None
        return root

# %%
# 314 lock

# %%
# 96 ########################################################################################################################################
class Solution(object):
    def numTrees(self, n):
        """
        :type n: int
        :rtype: int
        """
        T = [1, 1, 2] + [0] * (n - 2)
        for i in range(3, n + 1):
            mid, remainder = divmod(i, 2)
            for j in range(mid):
                T[i] += T[j] * T[i - j - 1]
            T[i] *= 2
            if remainder:
                T[i] += T[mid] * T[mid]
        return T[n]

# recursive
class Solution(object):
    def numTrees(self, n):
        """
        :type n: int
        :rtype: int
        """
        mem_map = {0:1, 1:1, 2:2}
        if n in mem_map:
            return mem_map[n]
        mid, remainder = divmod(n, 2)
        res = 0
        for i in range(mid):
            res += self.numTrees(i) * self.numTrees(n - i - 1)
        res *= 2
        if remainder:
            res += self.numTrees(mid) * self.numTrees(mid)
        mem_map[n] = res
        return res
